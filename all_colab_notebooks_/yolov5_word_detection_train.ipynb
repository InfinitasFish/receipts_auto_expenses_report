# %% [markdown]
# # Full Dataset Train Iterations

# %%
import gc
import torch

gc.collect()
torch.cuda.empty_cache()

# %%
# !python3 -m torch.distributed.run --nproc_per_node 2 ./yolov5/train.py --data ./docbank_short_with_additions_0107/docbank_short_with_additions_0107/dataset.yaml --epochs 350 --imgsz 1024 --weights '' --cfg ./configs/yolov5m.yaml --workers 4 --batch-size 20 --single-cls --patience 30 --optimizer Adam --device 0,1 --label-smoothing 0.1 --sync-bn --hyp ./configs/hyp.yaml
# Out:
# WARNING:__main__:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# ...

# %%
# dataset contains examples from docbank, SROIE, rus receipts and documents
# result model has Recall 0.69, I have a little theory that yolo can't detect all words, because there is a lot of them on some examples, due to some architecture limitations
# the idea is to somehow add more detection heads to the model and train it again
